# %%
from dotenv import load_dotenv
import os
import base64
from requests import post,get
import json
import pprint
import requests

load_dotenv()

client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")

def get_token():
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode('utf-8')
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization" : "Basic "+ auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}
    result = post(url, headers=headers, data=data)
    json_result = json.loads(result.content)
    token = json_result["access_token"]
    return token

# %%
def get_auth_header(token):
    return {"Authorization": "Bearer " + token}

# %%
def search_for_artist(token, artist_name):
    url = "https://api.spotify.com/v1/search"
    headers = get_auth_header(token)
    query = f"?q={artist_name}&type=artist&limit=1"
    query_url = url + query
    result= get(query_url, headers = headers)
    json_result = json.loads(result.content)["artists"]["items"]
    if len(json_result) == 0:
        print("No artist with this name exists")
        return None
    
    return json_result[0]

# %%
def get_songs_recommendations(token, artist_id, min_popularity, max_popularity):
    url = f"https://api.spotify.com/v1/recommendations?limit=100&market=US&seed_artists={artist_id}&min_popularity={min_popularity}&max_popularity={max_popularity}"
    headers = get_auth_header(token)
    result = get(url, headers= headers)
    json_result=json.loads(result.content)
    return json_result['tracks']

# %%
def get_songs_by_artist(token, artist_id):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks?country=US"
    headers = get_auth_header(token)
    result = get(url, headers= headers)
    json_result=json.loads(result.content)["tracks"]
    return json_result

# %%
token = get_token()
print(token)
# Out:
# BQDgZce88a7oK76Mcdmu_ZzitKq5rgCR3J3JbG64AaeP88IqIlUEAhG8IY2tw4o3Oi5V80GCEDjvuLN0Ha_KWjgOhb3ffBAl06_FWMNVV1oc2SkCy3o

# %%
artist_input = input("What artist are you looking for")

# %%
popularity = int(input("How popular do you want the recommendations to be? (0-100)"))

if popularity <10:
    min_popularty = 0
    max_popularity = popularity +10
elif popularity >90:
    min_popularty =popularity -10
    max_popularity = 100
else:
    min_popularty= popularity - 10
    max_popularity = popularity +10
    
print(min_popularty, max_popularity)
# Out:
# 70 90

# %%
result = search_for_artist(token, artist_input)
artist_id = result["id"]
songs = get_songs_recommendations(token, artist_id, min_popularty, max_popularity)


recommended_song_list = []
recommended_song_id = []

for song in songs:
    # print(song['name'])
    # print(song['id'])
    recommended_song_id.append(song['id'])
    for artist in song['artists']:
        # print(artist['name'])
        # print("------------")
        dict = {
            'name' : song['name'],
            'artist' : artist['name'],
            'id': song['id'],
            'popularity' : song['popularity'],

        }
        recommended_song_list.append(dict)


print(recommended_song_list)
print(recommended_song_id)
# Out:
# [{'name': 'Adore You', 'artist': 'Harry Styles', 'id': '3jjujdWJ72nww5eGnfs2E7', 'popularity': 88}, {'name': 'Left and Right (Feat. Jung Kook of BTS)', 'artist': 'Charlie Puth', 'id': '5Odq8ohlgIbQKMZivbWkEo', 'popularity': 88}, {'name': 'Left and Right (Feat. Jung Kook of BTS)', 'artist': 'Jung Kook', 'id': '5Odq8ohlgIbQKMZivbWkEo', 'popularity': 88}, {'name': 'Left and Right (Feat. Jung Kook of BTS)', 'artist': 'BTS', 'id': '5Odq8ohlgIbQKMZivbWkEo', 'popularity': 88}, {'name': 'Lose Somebody', 'artist': 'Kygo', 'id': '1sgDyuLooyvEML4oHspNza', 'popularity': 74}, {'name': 'Lose Somebody', 'artist': 'OneRepublic', 'id': '1sgDyuLooyvEML4oHspNza', 'popularity': 74}, {'name': 'hate u love u', 'artist': "Olivia O'Brien", 'id': '6ATgDc6e4sPn84hvJsAmPt', 'popularity': 74}, {'name': 'Here With Me', 'artist': 'Marshmello', 'id': '5icOoE6VgqFKohjWWNp0Ac', 'popularity': 77}, {'name': 'Here With Me', 'artist': 'CHVRCHES', 'id': '5icOoE6VgqFKohjWWNp0Ac', 'popularity': 77}, {'name': 'Never Not', 'artist': 'Lauv', 'id': '3ZPBZH2k9p306C1bu7bkhC', 'popularity': 74}, {'name': 'PILLOWTALK', 'artist': 'ZAYN', 'id': '0PDUDa38GO8lMxLCRc4lL1', 'popularity': 81}, {'name': 'Lonely (with benny blanco)', 'artist': 'Justin Bieber', 'id': '3S8jK1mGzQi24ilFb45DAZ', 'popularity': 75}, {'name': 'Lonely (with benny blanco)', 'artist': 'benny blanco', 'id': '3S8jK1mGzQi24ilFb45DAZ', 'popularity': 75}, {'name': 'When You Love Someone', 'artist': 'James TW', 'id': '0TXNKTzawI6VgLoA9UauRp', 'popularity': 76}, {'name': 'Circles', 'artist': 'Post Malone', 'id': '21jGcNKet2qwijlDFuPiPb', 'popularity': 90}, {'name': 'Lose You To Love Me', 'artist': 'Selena Gomez', 'id': '4l0Mvzj72xxOpRrp6h8nHi', 'popularity': 84}, {'name': 'Black And White', 'artist': 'Niall Horan', 'id': '7rpNuuoMbid56XkDsx2FjE', 'popularity': 70}, {'name': 'My Stupid Heart (with Lauv)', 'artist': 'Walk off the Earth', 'id': '1SVOLTmC627fn0XY9ltvx2', 'popularity': 70}, {'name': 'My Stupid Heart (with Lauv)', 'artist': 'Lauv', 'id': '1SVOLTmC627fn0XY9ltvx2', 'popularity': 70}, {'name': 'Tequila', 'artist': 'Dan + Shay', 'id': '42fw0rxRO2xbesF6mJfd4Y', 'popularity': 78}, {'name': "We Don't Talk Anymore (feat. Selena Gomez)", 'artist': 'Charlie Puth', 'id': '37FXw5QGFN7uwwsLy8uAc0', 'popularity': 72}, {'name': "We Don't Talk Anymore (feat. Selena Gomez)", 'artist': 'Selena Gomez', 'id': '37FXw5QGFN7uwwsLy8uAc0', 'popularity': 72}, {'name': 'If the World Was Ending (feat. Julia Michaels)', 'artist': 'JP Saxe', 'id': '77MdvMx9L4ZQuLhhn3o21h', 'popularity': 76}, {'name': 'If the World Was Ending (feat. Julia Michaels)', 'artist': 'Julia Michaels', 'id': '77MdvMx9L4ZQuLhhn3o21h', 'popularity': 76}, {'name': 'Ghost', 'artist': 'Justin Bieber', 'id': '6I3mqTwhRpn34SLVafSH7G', 'popularity': 90}, {'name': "They Don't Know About Us", 'artist': 'One Direction', 'id': '6M31fPFCYB8Job3
# %%
top_songs_by_artist = get_songs_by_artist(token, artist_id)

song_list = []
song_id = []

for song in top_songs_by_artist:
    # print(song['name'])
    # print(song['id'])
    song_id.append(song['id'])
    for artist in song['artists']:
        # print(artist['name'])
        # print("------------")
        dict = {
            'name' : song['name'],
            'artist' : artist['name'],
            'id': song['id'],
            'popularity' : song['popularity']
        }
        song_list.append(dict)


print(song_list)
print(song_id)
# Out:
# [{'name': 'I Like Me Better', 'artist': 'Lauv', 'id': '0EcQcdcbQeVJn9fknj44Be', 'popularity': 85}, {'name': 'Steal The Show - From "Elemental"', 'artist': 'Lauv', 'id': '6R5fYCySNHrqo4Og6O1ppn', 'popularity': 78}, {'name': "i'm so tired...", 'artist': 'Lauv', 'id': '7LpMG3AEaIJgs62HQhAa91', 'popularity': 78}, {'name': "i'm so tired...", 'artist': 'Troye Sivan', 'id': '7LpMG3AEaIJgs62HQhAa91', 'popularity': 78}, {'name': 'Who', 'artist': 'Lauv', 'id': '0pSqYDTjY1Xt86usTQslAx', 'popularity': 76}, {'name': 'Who', 'artist': 'BTS', 'id': '0pSqYDTjY1Xt86usTQslAx', 'popularity': 76}, {'name': 'Paris in the Rain', 'artist': 'Lauv', 'id': '2MOoIbJWIYikwIXjBDe26i', 'popularity': 75}, {'name': "All 4 Nothing (I'm So In Love)", 'artist': 'Lauv', 'id': '7I5WT7DtpwSAhEeDLpZEfm', 'popularity': 71}, {'name': 'Never Not', 'artist': 'Lauv', 'id': '3ZPBZH2k9p306C1bu7bkhC', 'popularity': 74}, {'name': 'Feelings', 'artist': 'Lauv', 'id': '6r3duEAfFTH83DuoywkG20', 'popularity': 73}, {'name': 'Mean It', 'artist': 'Lauv', 'id': '6mXdCcFnPKQznj4CmMRmHC', 'popularity': 72}, {'name': 'Mean It', 'artist': 'LANY', 'id': '6mXdCcFnPKQznj4CmMRmHC', 'popularity': 72}, {'name': "fuck, i'm lonely", 'artist': 'Lauv', 'id': '2RNsweBBb1a6tAHXQtt2xH', 'popularity': 70}, {'name': "fuck, i'm lonely", 'artist': 'Anne-Marie', 'id': '2RNsweBBb1a6tAHXQtt2xH', 'popularity': 70}]
# ['0EcQcdcbQeVJn9fknj44Be', '6R5fYCySNHrqo4Og6O1ppn', '7LpMG3AEaIJgs62HQhAa91', '0pSqYDTjY1Xt86usTQslAx', '2MOoIbJWIYikwIXjBDe26i', '7I5WT7DtpwSAhEeDLpZEfm', '3ZPBZH2k9p306C1bu7bkhC', '6r3duEAfFTH83DuoywkG20', '6mXdCcFnPKQznj4CmMRmHC', '2RNsweBBb1a6tAHXQtt2xH']

# %%
def get_song_audio_features(token, song_id):
    url = f"https://api.spotify.com/v1/audio-features?ids={','.join(song_id)}"
    headers = get_auth_header(token)
    response = requests.get(url, headers = headers)
    if response.status_code == 200:
        json_result = response.json()  # Use .json() method to parse the JSON data
        return json_result
    else:
        print(f"Failed to fetch audio features. Status code: {response.status_code}")
        return None

    return(json_result)

# %%
recommended_features = get_song_audio_features(token, recommended_song_id)
top_artist_features = get_song_audio_features(token, song_id)
print(recommended_features['audio_features'])
# Out:
# [{'danceability': 0.676, 'energy': 0.771, 'key': 8, 'loudness': -3.675, 'mode': 1, 'speechiness': 0.0483, 'acousticness': 0.0237, 'instrumentalness': 7e-06, 'liveness': 0.102, 'valence': 0.569, 'tempo': 99.048, 'type': 'audio_features', 'id': '3jjujdWJ72nww5eGnfs2E7', 'uri': 'spotify:track:3jjujdWJ72nww5eGnfs2E7', 'track_href': 'https://api.spotify.com/v1/tracks/3jjujdWJ72nww5eGnfs2E7', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3jjujdWJ72nww5eGnfs2E7', 'duration_ms': 207133, 'time_signature': 4}, {'danceability': 0.881, 'energy': 0.592, 'key': 2, 'loudness': -4.898, 'mode': 1, 'speechiness': 0.0324, 'acousticness': 0.619, 'instrumentalness': 1.32e-05, 'liveness': 0.0901, 'valence': 0.719, 'tempo': 101.058, 'type': 'audio_features', 'id': '5Odq8ohlgIbQKMZivbWkEo', 'uri': 'spotify:track:5Odq8ohlgIbQKMZivbWkEo', 'track_href': 'https://api.spotify.com/v1/tracks/5Odq8ohlgIbQKMZivbWkEo', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Odq8ohlgIbQKMZivbWkEo', 'duration_ms': 154487, 'time_signature': 4}, {'danceability': 0.58, 'energy': 0.586, 'key': 1, 'loudness': -6.883, 'mode': 1, 'speechiness': 0.0357, 'acousticness': 0.344, 'instrumentalness': 0, 'liveness': 0.0755, 'valence': 0.507, 'tempo': 147.988, 'type': 'audio_features', 'id': '1sgDyuLooyvEML4oHspNza', 'uri': 'spotify:track:1sgDyuLooyvEML4oHspNza', 'track_href': 'https://api.spotify.com/v1/tracks/1sgDyuLooyvEML4oHspNza', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sgDyuLooyvEML4oHspNza', 'duration_ms': 199549, 'time_signature': 4}, {'danceability': 0.407, 'energy': 0.416, 'key': 6, 'loudness': -8.915, 'mode': 0, 'speechiness': 0.174, 'acousticness': 0.656, 'instrumentalness': 0, 'liveness': 0.0981, 'valence': 0.246, 'tempo': 176.947, 'type': 'audio_features', 'id': '6ATgDc6e4sPn84hvJsAmPt', 'uri': 'spotify:track:6ATgDc6e4sPn84hvJsAmPt', 'track_href': 'https://api.spotify.com/v1/tracks/6ATgDc6e4sPn84hvJsAmPt', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ATgDc6e4sPn84hvJsAmPt', 'duration_ms': 175467, 'time_signature': 4}, {'danceability': 0.791, 'energy': 0.565, 'key': 5, 'loudness': -3.933, 'mode': 0, 'speechiness': 0.0439, 'acousticness': 0.0623, 'instrumentalness': 0, 'liveness': 0.156, 'valence': 0.181, 'tempo': 99.961, 'type': 'audio_features', 'id': '5icOoE6VgqFKohjWWNp0Ac', 'uri': 'spotify:track:5icOoE6VgqFKohjWWNp0Ac', 'track_href': 'https://api.spotify.com/v1/tracks/5icOoE6VgqFKohjWWNp0Ac', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5icOoE6VgqFKohjWWNp0Ac', 'duration_ms': 156347, 'time_signature': 4}, {'danceability': 0.471, 'energy': 0.22, 'key': 5, 'loudness': -9.243, 'mode': 1, 'speechiness': 0.037, 'acousticness': 0.691, 'instrumentalness': 0, 'liveness': 0.104, 'valence': 0.26, 'tempo': 133.714, 'type': 'audio_features', 'id': '3ZPBZH2k9p306C1bu7bkhC', 'uri': 'spotify:track:3ZPBZH2k9p306C1bu7bkhC', 'track_href': 'https://api.spotify.com/v1/tracks/3ZPBZH2k9p306C1bu7bkhC', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZPBZH2k9p306C1bu7bkhC', 'duration_ms': 208000, 'time_signature': 4}, {'danceability': 0.584, 'energy': 0.7, 'key': 11, 'loudness': -4.275, 'mode': 1, 'speechiness': 0.0456, 'acousticness': 0.117, 'instrumentalness': 0, 'liveness': 0.0939, 'valence': 0.438, 'tempo': 124.944, 'type': 'audio_features', 'id': '0PDUDa38GO8lMxLCRc4lL1', 'uri': 'spotify:track:0PDUDa38GO8lMxLCRc4lL1', 'track_href': 'https://api.spotify.com/v1/tracks/0PDUDa38GO8lMxLCRc4lL1', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PDUDa38GO8lMxLCRc4lL1', 'duration_ms': 202747, 'time_signature': 4}, {'danceability': 0.619, 'energy': 0.241, 'key': 11, 'loudness': -7.102, 'mode': 0, 'speechiness': 0.046, 'acousticness': 0.9, 'instrumentalness': 0, 'liveness': 0.116, 'valence': 0.0719, 'tempo': 79.461, 'type': 'audio_features', 'id': '3S8jK1mGzQi24ilFb45DAZ', 'uri': 'spotify:track:3S8jK1mGzQi24ilFb45DAZ', 'track_href': 'https://api.spotify.com/v1/tracks/3S8jK1mGzQi24ilFb45DAZ', 'analysis ...

# %%
import pandas as pd
df_recommended_audiofeatures =pd.DataFrame(recommended_features['audio_features'])

df_top_artist_audiofeatures = pd.DataFrame(top_artist_features['audio_features'])

# %%
df_recommended_song_list = pd.DataFrame(recommended_song_list)
df_recommended_song_list = df_recommended_song_list.drop_duplicates(subset=['name']).reset_index(drop=True)

df_top_artist_song_list = pd.DataFrame(song_list)
df_top_artist_song_list = df_top_artist_song_list.drop_duplicates(subset=['name']).reset_index(drop=True)

# %%
recommendations_df = pd.merge(df_recommended_song_list, df_recommended_audiofeatures, on ='id')

recommendations_df['duration_s'] = recommendations_df['duration_ms'] / 1000
recommendations_df
# Out:
#                                               name            artist  \
# 0                                        Adore You      Harry Styles
# 1          Left and Right (Feat. Jung Kook of BTS)      Charlie Puth
# 2                                    Lose Somebody              Kygo
# 3                                    hate u love u    Olivia O'Brien
# 4                                     Here With Me        Marshmello
# ..                                             ...               ...
# 94                                 I Love You 3000  Stephanie Poetri
# 95                                I Like Me Better              Lauv
# 96  Don't Give Up On Me - (From "Five Feet Apart")      Andy Grammer
# 97                                   thank u, next     Ariana Grande
# 98                                       Graveyard            Halsey
#
#                         id  popularity  danceability  energy  key  loudness  \
# 0   3jjujdWJ72nww5eGnfs2E7          88         0.676   0.771    8    -3.675
# 1   5Odq8ohlgIbQKMZivbWkEo          88         0.881   0.592    2    -4.898
# 2   1sgDyuLooyvEML4oHspNza          74         0.580   0.586    1    -6.883
# 3   6ATgDc6e4sPn84hvJsAmPt          74         0.407   0.416    6    -8.915
# 4   5icOoE6VgqFKohjWWNp0Ac          77         0.791   0.565    5    -3.933
# ..                     ...         ...           ...     ...  ...       ...
# 94  3znQ9i61vfe2E7URHlOiyc          74         0.648   0.382    6    -7.850
# 95  0EcQcdcbQeVJn9fknj44Be          85         0.753   0.505    9    -7.621
# 96  5A3fPy30SN2wuzrahpcxvV          75         0.641   0.537    0    -5.452
# 97  3e9HZxeyfWwjeyPAMmWSSQ          84         0.717   0.653    1    -5.634
# 98  2ufmtcIFdFpuUYBPXK5f67          70         0.667   0.583   11    -5.127
#
#     mode  speechiness  ...  liveness  valence    tempo            type  \
# 0      1       0.0483  ...    0.1020   0.5690   99.048  audio_features
# 1      1       0.0324  ...    0.0901   0.7190  101.058  audio_features
# 2      1       0.0357  ...    0.0755   0.5070  147.988  audio_features
# 3      0       0.1740  ...    0.0981   0.2460  176.947  audio_features
# 4      0       0.0439  ...    0.1560   0.1810   99.961  audio_features
# ..   ...          ...  ...       ...      ...      ...             ...
# 94     1       0.0396  ...    0.3930   0.4080   90.099  audio_features
# 95     1       0.2550  ...    0.1040   0.4190   91.972  audio_features
# 96     0       0.0282  ...    0.1150   0.0681  112.864  audio_features
# 97     1       0.0658  ...    0.1010   0.4120  106.966  audio_features
# 98     0       0.0747  ...    0.1810   0.1870   92.043  audio_features
#
#                                      uri  \
# 0   spotify:track:3jjujdWJ72nww5eGnfs2E7
# 1   spotify:track:5Odq8ohlgIbQKMZivbWkEo
# 2   spotify:track:1sgDyuLooyvEML4oHspNza
# 3   spotify:track:6ATgDc6e4sPn84hvJsAmPt
# 4   spotify:track:5icOoE6VgqFKohjWWNp0Ac
# ..                                   ...
# 94  spotify:track:3znQ9i61vfe2E7URHlOiyc
# 95  spotify:track:0EcQcdcbQeVJn9fknj44Be
# 96  spotify:track:5A3fPy30SN2wuzrahpcxvV
# 97  spotify:track:3e9HZxeyfWwjeyPAMmWSSQ
# 98  spotify:track:2ufmtcIFdFpuUYBPXK5f67
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/3jjujdWJ72nw...
# 1   https://api.spotify.com/v1/tracks/5Odq8ohlgIbQ...
# 2   https://api.spotify.com/v1/tracks/1sgDyuLooyvE...
# 3   https://api.spotify.com/v1/tracks/6ATgDc6e4sPn...
# 4   https://api.spotify.com/v1/tracks/5icOoE6VgqFK...
# ..                                                ...
# 94  https://api.spotify.com/v1/tracks/3znQ9i61vfe2...
# 95  https://api.spotify.com/v1/tracks/0EcQcdcbQeVJ...
# 96  https://api.spotify.com/v1/tracks/5A3fPy30SN2w...
# 97  https://api.spotify.com/v1/tracks/3e9HZxeyfWwj...
# 98  https://api.spotify.com/v1/tracks/2ufmtcIFdFpu...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/3jju...      207133
# 1   https://api.spotify.com/v1/audio-analysis/5Odq...      154487
# 2   https://api.spotify.com/v1/audio-analysis/1sgD...      199549
# 3   https://api.spotify.com/v1/audio-analysis/6ATg...      175467
# 4   https://api.spotify.com/v1/audio-analysis/5icO...      156347
# ..                                                ...         ...
# 94  https://api.spotify.com/v1/audio-analysis/3znQ...      209734
# 95  https://api.spotify.com/v1/audio-analysis/0EcQ...      197437
# 96  https://api.spotify.com/v1/audio-analysis/5A3f...      196188
# 97  https://api.spotify.com/v1/audio-analysis/3e9H...      207320
# 98  https://api.spotify.com/v1/audio-analysis/2ufm...      181806
#
#    time_signature  duration_s
# 0               4     207.133
# 1               4     154.487
# 2               4     199.549
# 3               4     175.467
# 4               4     156.347
# ..            ...         ...
# 94              4     209.734
# 95              4     197.437
# 96              4     196.188
# 97              4     207.320
# 98              4     181.806
#
# [99 rows x 22 columns]

# %%
top_artist_df = pd.merge(df_top_artist_song_list, df_top_artist_audiofeatures, on ='id')
top_artist_df['duration_s'] = top_artist_df['duration_ms'] / 1000
top_artist_df
# Out:
#                                 name artist                      id  \
# 0                   I Like Me Better   Lauv  0EcQcdcbQeVJn9fknj44Be
# 1  Steal The Show - From "Elemental"   Lauv  6R5fYCySNHrqo4Og6O1ppn
# 2                    i'm so tired...   Lauv  7LpMG3AEaIJgs62HQhAa91
# 3                                Who   Lauv  0pSqYDTjY1Xt86usTQslAx
# 4                  Paris in the Rain   Lauv  2MOoIbJWIYikwIXjBDe26i
# 5     All 4 Nothing (I'm So In Love)   Lauv  7I5WT7DtpwSAhEeDLpZEfm
# 6                          Never Not   Lauv  3ZPBZH2k9p306C1bu7bkhC
# 7                           Feelings   Lauv  6r3duEAfFTH83DuoywkG20
# 8                            Mean It   Lauv  6mXdCcFnPKQznj4CmMRmHC
# 9                   fuck, i'm lonely   Lauv  2RNsweBBb1a6tAHXQtt2xH
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  ...  \
# 0          85         0.753   0.505    9    -7.621     1       0.2550  ...
# 1          78         0.620   0.640    7    -7.308     1       0.0305  ...
# 2          78         0.548   0.735   11    -7.572     1       0.2360  ...
# 3          76         0.632   0.337   11    -8.000     0       0.0330  ...
# 4          75         0.406   0.408    3    -9.419     1       0.0530  ...
# 5          71         0.720   0.819    1    -4.588     1       0.0362  ...
# 6          74         0.471   0.220    5    -9.243     1       0.0370  ...
# 7          73         0.700   0.394    9    -8.911     1       0.0328  ...
# 8          72         0.747   0.450    7    -8.543     1       0.0919  ...
# 9          70         0.809   0.547    9    -7.305     1       0.0614  ...
#
#    liveness  valence    tempo            type  \
# 0    0.1040   0.4190   91.972  audio_features
# 1    0.1400   0.4090   92.522  audio_features
# 2    0.1950   0.4980  101.252  audio_features
# 3    0.1040   0.0982  141.701  audio_features
# 4    0.3940   0.5250   79.705  audio_features
# 5    0.0606   0.8980  131.990  audio_features
# 6    0.1040   0.2600  133.714  audio_features
# 7    0.0801   0.2410  103.041  audio_features
# 8    0.1700   0.3290   96.001  audio_features
# 9    0.0540   0.7180   94.992  audio_features
#
#                                     uri  \
# 0  spotify:track:0EcQcdcbQeVJn9fknj44Be
# 1  spotify:track:6R5fYCySNHrqo4Og6O1ppn
# 2  spotify:track:7LpMG3AEaIJgs62HQhAa91
# 3  spotify:track:0pSqYDTjY1Xt86usTQslAx
# 4  spotify:track:2MOoIbJWIYikwIXjBDe26i
# 5  spotify:track:7I5WT7DtpwSAhEeDLpZEfm
# 6  spotify:track:3ZPBZH2k9p306C1bu7bkhC
# 7  spotify:track:6r3duEAfFTH83DuoywkG20
# 8  spotify:track:6mXdCcFnPKQznj4CmMRmHC
# 9  spotify:track:2RNsweBBb1a6tAHXQtt2xH
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0EcQcdcbQeVJ...
# 1  https://api.spotify.com/v1/tracks/6R5fYCySNHrq...
# 2  https://api.spotify.com/v1/tracks/7LpMG3AEaIJg...
# 3  https://api.spotify.com/v1/tracks/0pSqYDTjY1Xt...
# 4  https://api.spotify.com/v1/tracks/2MOoIbJWIYik...
# 5  https://api.spotify.com/v1/tracks/7I5WT7DtpwSA...
# 6  https://api.spotify.com/v1/tracks/3ZPBZH2k9p30...
# 7  https://api.spotify.com/v1/tracks/6r3duEAfFTH8...
# 8  https://api.spotify.com/v1/tracks/6mXdCcFnPKQz...
# 9  https://api.spotify.com/v1/tracks/2RNsweBBb1a6...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0EcQ...      197437
# 1  https://api.spotify.com/v1/audio-analysis/6R5f...      191779
# 2  https://api.spotify.com/v1/audio-analysis/7LpM...      162587
# 3  https://api.spotify.com/v1/audio-analysis/0pSq...      180413
# 4  https://api.spotify.com/v1/audio-analysis/2MOo...      204712
# 5  https://api.spotify.com/v1/audio-analysis/7I5W...      183014
# 6  https://api.spotify.com/v1/audio-analysis/3ZPB...      208000
# 7  https://api.spotify.com/v1/audio-analysis/6r3d...      189907
# 8  https://api.spotify.com/v1/audio-analysis/6mXd...      232853
# 9  https://api.spotify.com/v1/audio-analysis/2RNs...      198973
#
#   time_signature  duration_s
# 0              4     197.437
# 1              4     191.779
# 2              4     162.587
# 3              3     180.413
# 4              4     204.712
# 5              4     183.014
# 6              4     208.000
# 7              4     189.907
# 8              4     232.853
# 9              4     198.973
#
# [10 rows x 22 columns]

# %%
import sqlite3

# %%
connection = sqlite3.connect("spotify.sqlite")

# %%
recommendation_table = 'recommendation_table'
recommendations_df.to_sql(recommendation_table, connection, index = False, if_exists='replace')

top_artist_table = 'top_artist_table'
top_artist_df.to_sql(top_artist_table, connection, index = False, if_exists= 'replace')

connection.commit()
connection.close()
